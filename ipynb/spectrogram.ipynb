# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2 as cv
from numpy.fft import fft2, fftshift
import time
from IPython.display import clear_output


from pylab import rcParams
rcParams['figure.figsize'] = 16, 9

sys.path.append('..')

from utils.dataset import DatasetReader

# %%
dr = DatasetReader(dataset_path='../temp/PUC_DIR')

# %%
x_train, y_train, x_val, y_val, _, _ = dr.get_dataset(img_size=128)

# %%
data = np.asarray(y_train + y_val)

# %%
data[0]
# Out:
# array([[-4.68642684e-03, -8.08771234e-03, -1.10209137e-02, ...,
#          1.01934895e-02,  5.10402583e-03, -7.11788714e-04],
#        [-1.32379681e-02, -1.43956104e-02, -1.43699078e-02, ...,
#         -7.08081527e-04, -5.92620485e-03, -9.60417278e-03],
#        [-1.33944266e-02, -1.11563420e-02, -8.15335847e-03, ...,
#         -9.50882863e-03, -1.11095123e-02, -1.06763532e-02],
#        ...,
#        [ 7.08410662e-05,  1.01875412e-04,  1.24091021e-04, ...,
#         -1.03068696e-02, -9.82382521e-03, -8.31649080e-03],
#        [ 1.45637867e-04,  1.53763394e-04,  1.35066482e-04, ...,
#         -7.99663737e-03, -5.68886846e-03, -3.22091137e-03],
#        [ 9.24581036e-05,  3.52133247e-05, -6.82238824e-05, ...,
#         -3.20864748e-03, -9.74231109e-04,  7.88701465e-04]], dtype=float32)

# %%
plt.imshow(data[i], cmap='seismic')
plt.show()

# %%
for i in range(len(data)):
    clear_output()
    print(i)
    plt.imshow(np.abs(fftshift(fft2(data)))[i])
    plt.show()
    time.sleep(1)
# Out:
# 68
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-3f9b14f7ce15> in <module>
#       3     print(i)
#       4     plt.imshow(np.abs(fftshift(fft2(data)))[i])
# ----> 5     plt.show()
#       6     time.sleep(1)
#
# ~/.local/share/virtualenvs/super-resolution-_aszCJf7/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# ~/.local/share/virtualenvs/super-resolution-_aszCJf7/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ...

# %%
plt.imshow(np.abs(fftshift(fft2(data)[13])))
plt.show()
